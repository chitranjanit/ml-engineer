# %%
import matplotlib.pyplot as plt
#plot a line, implicitly creating a subplot(111)
plt.plot([1,2,3])
#now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. since this subplot will overlpa the
# first , the plot ( and its axes ) previously created , will be removed
plt.subplot(211)

#equivalent but more general
ax1=plt.subplot(2,2,1)

#add a subplot with no frame
ax2=plt.subplot(222,frameon=False)

#add a polar subplot
plt.subplot(233,projection='polar')

# add a red subplot that shares the x-axis with ax1
plt.subplot(244,sharex=ax1,facecolor='red')

#delete ax2 from the figure
plt.delaxes(ax2)

#add ax2 to the figure again
plt.subplot(ax2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-1af32922d260> in <module>
#      20
#      21 #delete ax2 from the figure
# ---> 22 plt.delaxes(ax2)
#      23
#      24 #add ax2 to the figure again
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in delaxes(ax)
#     881     if ax is None:
#     882         ax = gca()
# --> 883     ax.figure.delaxes(ax)
#     884
#     885
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in delaxes(self, ax)
#    1029         current axes.
#    1030         """
# -> 1031         self._axstack.remove(ax)
#    1032         for func in self._axobservers:
#    1033             func(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in remove(self, a)
#     104     def remove(self, a):
#     105         """Remove the axes from the stack."""
# --> 106         super().remove(self._entry_from_axes(a))
#     107
#     108     def bubble(self, a):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in _entry_from_axes(self, e)
#      99
#     100     def _entry_from_axes(self, e):
# --> 101         ind, k = {a: (ind, k) for k, (ind, a) in self._elements}[e]
#     102         return (k, (ind, e))
#     103
#
# KeyError: <matplotlib.axes._subplots.AxesSubplot object at 0x111de6250>

# %%
#Polar Demo
import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0,2,0.01)
theta = 2*np.pi*r

ax = plt.subplot(111,projection='polar')
ax.plot(theta,r)
ax.set_rmax(2)
ax.set_rticks([0.5,1,1.5,2])#Less radial ticks
ax.set_rlabel_position(-22.5)#Move radial labels away from plotted line
ax.grid(True)

ax.set_title('A line plot on a polar axis',va='bottom')
plt.show()

# %%
#Nan Test
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0,1.0+0.01,0.01)
s = np.cos(2*2*np.pi*t)
t[41:60] = np.nan

plt.subplot(2,1,1)
plt.plot(t,s,'-',lw=2)

plt.xlabel('time(s)')
plt.ylabel('voltage(mV)')
plt.title('A sine wave with a gap of NaNs beetween 0.4 and 0.6')
plt.grid(True)

plt.subplot(2,1,2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t,s,'-',lw=2)
plt.title('Also with Nan in first and last point')

plt.xlabel('time(s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#PSD Demo
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec

#fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0,10,dt)
nse = np.random.randn(len(t))
r = np.exp(-t/0.05)

cnse = np.convolve(nse,r)*dt
cnse = cnse[:len(t)]
s = 0.1*np.sin(2*np.pi*t)+cnse

plt.subplot(211)
plt.plot(t,s)
plt.subplot(212)
plt.psd(s,512,1/dt)

plt.show()

# %%
#Periodogram
